# %%
# %run main.py
# Out:
# mqtt client initialized
# scanThings CALLED
# scanThings CALLED
# scanThings ENDED
# scanThings ENDED
# ### test thing list
# payload is  <class 'str'>
# sendRequest BEGIN
# cmu/gcf-framework
# { name: just a Phone, uuidGoPhone-1}
# {"destination": ["GoPhone-1"], "messageType": "I", "command": "IDENTIFY", "payload": ["PARAMETERS={}"], "version": 1, "deviceID": "IOT Scripting", "contextType": "IOT"}
# sendRequest END
# ### test find all
# payload is  <class 'str'>
# sendRequest BEGIN
# cmu/gcf-framework
# { name: just a Phone, uuidGoPhone-1}
# {"destination": ["GoPhone-1"], "messageType": "I", "command": "IDENTIFY", "payload": ["PARAMETERS={}"], "version": 1, "deviceID": "IOT Scripting", "contextType": "IOT"}
# sendRequest END
# ### test find phone
# payload is  <class 'str'>
# sendRequest BEGIN
# cmu/gcf-framework
# { name: just a Phone, uuidGoPhone-1}
# ...

# %%
Please.find(All, "light").light()
# Out:
# scanThings CALLED
# scanThings ENDED
# scanThings CALLED
# scanThings ENDED
# scanThings CALLED
# scanThings ENDED
# scanThings CALLED
# scanThings ENDED
# scanThings CALLED
# scanThings ENDED
# scanThings CALLED
# scanThings ENDED
# scanThings CALLED
# scanThings ENDED
# scanThings CALLED
# scanThings ENDED
# scanThings CALLED
# scanThings ENDED
# scanThings CALLED
# scanThings ENDED
# scanThings CALLED
# scanThings ENDED

# %%
import lightblue
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-7fea8c968f08> in <module>()
# ----> 1 import lightblue
#
# /usr/local/lib/python3.4/site-packages/lightblue/__init__.py in <module>()
#     158
#     159 # import implementation modules
# --> 160 from _lightblue import *
#     161 from _lightbluecommon import *
#     162 import obex     # plus submodule
#
# ImportError: No module named '_lightblue'
# scanThings CALLED
# scanThings ENDED
# scanThings CALLED
# scanThings ENDED
# scanThings CALLED
# scanThings ENDED
# scanThings CALLED
# scanThings ENDED
